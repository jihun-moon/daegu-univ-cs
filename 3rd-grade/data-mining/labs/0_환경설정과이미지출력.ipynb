# %%
# !pwd
# Out:
# /content

# %%
# !ls ./drive/MyDrive/ -la
# Out:
# total 5
# -rw------- 1 root root  178 Aug  7 17:07 '2. 추진 방법 및 과정'$'\n''가. 1단계: 데이터 수집 및 전처리 과정'$'\n\t''본 프로젝트의 1단....gdoc'
# drwx------ 2 root root 4096 Sep 11 06:08 'Colab Notebooks'

# %%
print(12*37)
print('Python' + ' Hello World!')
# Out:
# 444
# Python Hello World!

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./drive/MyDrive/du.png')

plt.imshow(img)

# %%
# !pip install scikit-learn
